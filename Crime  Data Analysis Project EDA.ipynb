# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/Users/nitishkumar/Downloads/Data_sets/crime_data.csv")

# %%
data
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1       2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3       2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4       2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# ...            ...         ...      ...   ...          ...       ...     ...
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
# ...

# %%
data.head()
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0  2022-04-12  2020-10-01    00:01    19    Mission         1     821
# 1  2023-01-05  2020-02-01    08:00     2    Rampart         2     812
# 2  2023-03-21  2020-03-15    12:00    19    Mission         2     812
# 3  2023-06-04  2020-07-01    12:00    20    Olympic         2     812
# 4  2022-02-02  2020-02-09    12:00    11  Northeast         2     930
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...         8        F
# 1  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 2  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 4             CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F
#
#   Vict Descent                                   Premis Desc  \
# ...

# %%
data.tail()
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 230540                                 BRANDISH WEAPON        38        M
# 230541                                         ROBBERY        23        F
# 230542                                         ROBBERY        65        F
# 230543               INTIMATE PARTNER - SIMPLE ASSAULT        35        M
# 230544  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25        F
#
#        Vict Descent             Premis Desc  \
# ...

# %%
data.columns
# Out:
# Index(['Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Part 1-2',
#        'Crm Cd', 'Crm Cd Desc', 'Vict Age', 'Vict Sex', 'Vict Descent',
#        'Premis Desc', 'Weapon Desc', 'Status Desc', 'LOCATION'],
#       dtype='object')

# %%
# rows and columns
data.shape
# Out:
# (230545, 15)

# %%
data.shape[0]
# Out:
# 230545

# %%
data.shape[1]
# Out:
# 15

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230545 entries, 0 to 230544
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date Rptd     230545 non-null  object
#  1   DATE OCC      230545 non-null  object
#  2   TIME OCC      230545 non-null  object
#  3   AREA          230545 non-null  int64
#  4   AREA NAME     230545 non-null  object
#  5   Part 1-2      230545 non-null  int64
#  6   Crm Cd        230545 non-null  int64
#  7   Crm Cd Desc   230545 non-null  object
#  8   Vict Age      230545 non-null  int64
#  9   Vict Sex      230545 non-null  object
#  10  Vict Descent  230545 non-null  object
#  11  Premis Desc   230545 non-null  object
#  12  Weapon Desc   230545 non-null  object
#  13  Status Desc   230545 non-null  object
#  14  LOCATION      230545 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 26.4+ MB

# %%
data.describe()
# Out:
#                 AREA       Part 1-2         Crm Cd       Vict Age
# count  230545.000000  230545.000000  230545.000000  230545.000000
# mean       10.466881       1.544991     508.044629      34.451513
# std         6.225582       0.497973     240.542475      18.003355
# min         1.000000       1.000000     110.000000      -2.000000
# 25%         5.000000       1.000000     230.000000      23.000000
# 50%        11.000000       2.000000     624.000000      33.000000
# 75%        16.000000       2.000000     626.000000      46.000000
# max        21.000000       2.000000     956.000000      99.000000

# %%
#to find null values
data.isnull().sum()
# Out:
# Date Rptd       0
# DATE OCC        0
# TIME OCC        0
# AREA            0
# AREA NAME       0
# Part 1-2        0
# Crm Cd          0
# Crm Cd Desc     0
# Vict Age        0
# Vict Sex        0
# Vict Descent    0
# Premis Desc     0
# Weapon Desc     0
# Status Desc     0
# LOCATION        0
# dtype: int64

# %%
data.isnull().head(10)
# Out:
#    Date Rptd  DATE OCC  TIME OCC   AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0      False     False     False  False      False     False   False
# 1      False     False     False  False      False     False   False
# 2      False     False     False  False      False     False   False
# 3      False     False     False  False      False     False   False
# 4      False     False     False  False      False     False   False
# 5      False     False     False  False      False     False   False
# 6      False     False     False  False      False     False   False
# 7      False     False     False  False      False     False   False
# 8      False     False     False  False      False     False   False
# 9      False     False     False  False      False     False   False
#
#    Crm Cd Desc  Vict Age  Vict Sex  Vict Descent  Premis Desc  Weapon Desc  \
# 0        False     False     False         False        False        False
# ...

# %%
# only specific row
data[data.index == 5]
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA AREA NAME  Part 1-2  Crm Cd  \
# 5  2022-04-28  2020-03-30    16:30     8   West LA         2     624
#
#                 Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 5  BATTERY - SIMPLE ASSAULT        24        F            O
#
#               Premis Desc                                     Weapon Desc  \
# 5  SINGLE FAMILY DWELLING  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
#
#    Status Desc                                 LOCATION
# 5  Invest Cont  1200 S  WESTGATE                     AV

# %%
#Isolating two or more rows using [ ] 
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(2,15))]
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 2   2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3   2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4   2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# 5   2022-04-28  2020-03-30    16:30     8      West LA         2     624
# 6   2021-09-27  2020-11-26    20:00    12  77th Street         2     930
# 7   2022-01-06  2020-10-30    00:01    15  N Hollywood         2     812
# 8   2023-06-02  2020-05-31    04:30     6    Hollywood         1     310
# 9   2023-11-27  2020-09-13    21:00     8      West LA         2     626
# 10  2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 11  2022-04-07  2020-01-01    08:00    12  77th Street         2     812
# 12  2022-07-06  2020-06-30    14:00     3    Southwest         2     626
# 13  2022-03-21  2020-10-01    22:00     2      Rampart         1     210
# ...

# %%
data.loc[2:10]
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 2   2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3   2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4   2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# 5   2022-04-28  2020-03-30    16:30     8      West LA         2     624
# 6   2021-09-27  2020-11-26    20:00    12  77th Street         2     930
# 7   2022-01-06  2020-10-30    00:01    15  N Hollywood         2     812
# 8   2023-06-02  2020-05-31    04:30     6    Hollywood         1     310
# 9   2023-11-27  2020-09-13    21:00     8      West LA         2     626
# 10  2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
#
#                                           Crm Cd Desc  Vict Age Vict Sex  \
# 2   CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3   CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# ...

# %%
data['Weapon Desc'].value_counts()
# Out:
# Weapon Desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    123563
# UNKNOWN WEAPON/OTHER WEAPON                        24639
# VERBAL THREAT                                      16998
# HAND GUN                                           14710
# SEMI-AUTOMATIC PISTOL                               5198
#                                                    ...
# UZI SEMIAUTOMATIC ASSAULT RIFLE                        7
# ANTIQUE FIREARM                                        6
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          1
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    1
# Name: count, Length: 77, dtype: int64

# %%
data['Premis Desc'].value_counts()
# Out:
# Premis Desc
# STREET                                          49065
# SINGLE FAMILY DWELLING                          41837
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)    38697
# SIDEWALK                                        22223
# PARKING LOT                                     12869
#                                                 ...
# DRIVE THRU BANKING (WINDOW)*                        1
# MTA - ORANGE LINE - VALLEY COLLEGE                  1
# FINANCE COMPANY                                     1
# MTA - SILVER LINE - PACIFIC COAST HWY               1
# MTA - SILVER LINE - ROSECRANS                       1
# Name: count, Length: 293, dtype: int64

# %%
data['Vict Age'].value_counts()
# Out:
# Vict Age
#  0     18492
#  30     6496
#  31     6021
#  28     5977
#  27     5943
#        ...
#  96       20
#  97       16
#  95       12
# -2         2
# -1         1
# Name: count, Length: 101, dtype: int64

# %%
# to find mean value
mean_value=data['Vict Age'].mean()
print(mean_value)
# Out:
# 34.451512719859466

# %%
# to find median value
median_value=data['Vict Age'].median()
print(median_value)
# Out:
# 33.0

# %%
# to find mode value
mode_value=data['Vict Age'].mode()[0]
print(mode_value)
# Out:
# 0

# %%
#Count crimes by area
data['AREA NAME'].value_counts()
# Out:
# AREA NAME
# 77th Street    20045
# Central        18206
# Southeast      15309
# Hollywood      14463
# Newton         14071
# Southwest      13926
# Rampart        13229
# Olympic        12325
# Pacific        10713
# Harbor          9386
# N Hollywood     9034
# Hollenbeck      8930
# West Valley     8741
# Mission         8621
# Wilshire        8484
# Topanga         7748
# Van Nuys        7665
# Northeast       7603
# West LA         7485
# Devonshire      7421
# Foothill        7140
# Name: count, dtype: int64

# %%
#Count crimes by crime code description
data['Crm Cd Desc'].value_counts()
# Out:
# Crm Cd Desc
# BATTERY - SIMPLE ASSAULT                          53070
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    38259
# INTIMATE PARTNER - SIMPLE ASSAULT                 32792
# ROBBERY                                           22846
# CRIMINAL THREATS - NO WEAPON DISPLAYED            13695
#                                                   ...
# COUNTERFEIT                                           1
# DRIVING WITHOUT OWNER CONSENT (DWOC)                  1
# CHILD ABANDONMENT                                     1
# TILL TAP - PETTY ($950 & UNDER)                       1
# DISHONEST EMPLOYEE - PETTY THEFT                      1
# Name: count, Length: 116, dtype: int64

# %%
#Crime distribution by sex
data['Vict Sex'].value_counts()
# Out:
# Vict Sex
# M    111540
# F    105368
# X     13618
# H        19
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
data.head(15)
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0   2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1   2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2   2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3   2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4   2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# 5   2022-04-28  2020-03-30    16:30     8      West LA         2     624
# 6   2021-09-27  2020-11-26    20:00    12  77th Street         2     930
# 7   2022-01-06  2020-10-30    00:01    15  N Hollywood         2     812
# 8   2023-06-02  2020-05-31    04:30     6    Hollywood         1     310
# 9   2023-11-27  2020-09-13    21:00     8      West LA         2     626
# 10  2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 11  2022-04-07  2020-01-01    08:00    12  77th Street         2     812
# ...

# %%
# Extract Year from 'DATE OCC' and analyze crimes by year
data['DATE OCC'] = pd.to_datetime(data['DATE OCC'], errors='coerce')
data['Year OCC'] = data['DATE OCC'].dt.year
data['Year OCC'].value_counts().sort_index()
# Out:
# Year OCC
# 2020     1226
# 2021    73805
# 2022    77635
# 2023    77879
# Name: count, dtype: int64

# %%
# Set up the style for the plots
sns.set(style="whitegrid")

# %%
# Plot Crimes by Year
plt.figure(figsize=(8, 5))
data['Year OCC'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title('Crimes by Year', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=0)
plt.show()

# %%
# Analyze crimes by time of day (categorize into time buckets)
data['TIME OCC'] = pd.to_datetime(data['TIME OCC'], format='%H:%M', errors='coerce').dt.hour
def categorize_time(hour):
    if pd.isnull(hour):
        return 'Unknown'
    elif 0 <= hour < 6:
        return 'Night (12 AM - 6 AM)'
    elif 6 <= hour < 12:
        return 'Morning (6 AM - 12 PM)'
    elif 12 <= hour < 18:
        return 'Afternoon (12 PM - 6 PM)'
    else:
        return 'Evening (6 PM - 12 AM)'

data['Time Category'] = data['TIME OCC'].apply(categorize_time)
data['Time Category'].value_counts()
# Out:
# Time Category
# Evening (6 PM - 12 AM)      74193
# Afternoon (12 PM - 6 PM)    72027
# Morning (6 AM - 12 PM)      45346
# Night (12 AM - 6 AM)        38979
# Name: count, dtype: int64

# %%
# Plot Crimes by Time of Day Category
plt.figure(figsize=(8, 5))
data['Time Category'].value_counts().plot(kind='bar', color='salmon')
plt.title('Crimes by Time of Day', fontsize=16)
plt.xlabel('Time of Day', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Plot Crimes by Premises Description
plt.figure(figsize=(18, 6))
data['Premis Desc'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Crimes by Premises Description', fontsize=16)
plt.xlabel('Premises Type', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
#Plot Average Victim Age by Crime Description
plt.figure(figsize=(10, 20))
avg_age_by_crime.plot(kind='barh', color='purple')
plt.title('Average Victim Age by Crime Description', fontsize=16)
plt.xlabel('Average Age', fontsize=12)
plt.ylabel('Crime Type', fontsize=12)
plt.show()

# %%
# Heatmap for Crimes by Premises and Crime Type
plt.figure(figsize=(12, 20))
crimes_by_premises_crime = data.groupby(['Premis Desc', 'Crm Cd Desc']).size().unstack(fill_value=0)
sns.heatmap(crimes_by_premises_crime, annot=True, fmt="d", cmap="Blues", linewidths=.5)
plt.title('Crimes by Premises and Crime Type', fontsize=16)
plt.xlabel('Crime Type', fontsize=12)
plt.ylabel('Premises Type', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
# Crimes by Gender and Descent
plt.figure(figsize=(10, 6))
sns.countplot(data, x='Vict Sex', hue='Vict Descent', palette='Set2')
plt.title('Crimes by Gender and Descent', fontsize=16)
plt.xlabel('Victim Gender', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=0)
plt.show()

# %%
# Crimes by Status (e.g., Investigation Ongoing, Adult Arrest)
plt.figure(figsize=(10, 6))
data['Status Desc'].value_counts().plot(kind='bar', color='darkorange')
plt.title('Crimes by Investigation Status', fontsize=16)
plt.xlabel('Status', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
#Geographic Crime Distribution (using location data if available)
plt.figure(figsize=(10, 6))
data['LOCATION'].value_counts().head(10).plot(kind='barh', color='lightblue')
plt.title('Top 10 Locations with Most Crimes', fontsize=16)
plt.xlabel('Number of Crimes', fontsize=12)
plt.ylabel('Location', fontsize=12)
plt.show()

# %%
#Crimes by Weapon Type
plt.figure(figsize=(10, 20))
sns.countplot(data, y='Weapon Desc', palette='coolwarm',hue='Weapon Desc', order=data['Weapon Desc'].value_counts().index)
plt.title('Crimes by Weapon Type', fontsize=16)
plt.xlabel('Number of Crimes', fontsize=12)
plt.ylabel('Weapon Type', fontsize=12)
plt.show()

# %%
#Victim Age Distribution (Histogram)
plt.figure(figsize=(10, 6))
sns.histplot(data['Vict Age'], bins=20, kde=True, color='purple')
plt.title('Victim Age Distribution', fontsize=16)
plt.xlabel('Victim Age', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
#Crimes by Area (AREA NAME)
plt.figure(figsize=(10, 6))
data['AREA NAME'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Crimes by Area Name', fontsize=16)
plt.xlabel('Area', fontsize=12)
plt.ylabel('Number of Crimes', fontsize=12)
plt.xticks(rotation=45)
plt.show()
